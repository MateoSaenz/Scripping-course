# %%
import os
directories = os.listdir("C:/Users/mateo/OneDrive/Documentos/IMT NORD EUROPE/AÑO 2/Logistics and sim")
directories [-1] #last item in the list
# Out:
# 'scheduling.ipynb'

# %%
type(directories)
# Out:
# list

# %%
directories
# Out:
# ['com_ine.ipynb',
#  'Knapsack model',
#  'Lab_2_transportation_model.pdf',
#  'model.ipynb',
#  'Projet1.ipynb',
#  'projet1.py',
#  'SAENZ_ORTIZ_Mateo_Lab_2.zip',
#  'SAENZ_ORTIZ_Mateo_Lab_3',
#  'SAENZ_ORTIZ_Mateo_Lab_3.zip',
#  'SAENZ_ORTIZ_Mateo_Lab_4',
#  'SAENZ_ORTIZ_Mateo_Lab_4.zip',
#  'scheduling.ipynb']

# %% [markdown]
# DICTIONARY :
# keys and values

# %%
contacts ={"name": "mateo","surname": "saenz"}

# %%
print(contacts["name"])
print(contacts.get("name"))
print(contacts.get("cellphone"))
# Out:
# mateo
# mateo
# None

# %%
contacts["cellphone"] = 215484518
print (contacts.get("cellphone"))
# Out:
# 215484518

# %% [markdown]
# TURPLE: just is an array where each item have 2 items

# %% [markdown]
# SETS: allow the uniques values, is gonna show me the unique values

# %%
unique ={1,2,3,1,1,5}
unique
# Out:
# {1, 2, 3, 5}

# %%
unique.add(7)
unique
# Out:
# {1, 2, 3, 5, 7}

# %% [markdown]
# Itereations in data structures

# %%
names = ["janis", "anna", "juan", "alejandr0", "ricardo"]

for n in names: 
    if len(n) > 5:
        print (n)
# Out:
# alejandr0
# ricardo

# %%
long_names= [n for n in names if len(n) > 5]
long_names
# Out:
# ['alejandr0', 'ricardo']

# %% [markdown]
# in dictionarys

# %%
contact = {"mateo": "mateo@gmail.com", "elisa" : "elisakjij@gmail.com", "esteban": "esteban@gmail.com"}
contact
# Out:
# {'mateo': 'mateo@gmail.com',
#  'elisa': 'elisakjij@gmail.com',
#  'esteban': 'esteban@gmail.com'}

# %%
#just print the keys
for mail in contact: 
    print(mail)
# Out:
# mateo
# elisa
# esteban

# %%
#il va chercher tout.
for name,mail in contact.items():
    if len(mail)> 15:
        print(name, mail)
# Out:
# elisa elisakjij@gmail.com
# esteban esteban@gmail.com

# %%
# Out:
#   File "<ipython-input-1-9cb980c7aa8f>", line 1
#     -- Create sample table
#               ^
# SyntaxError: invalid syntax
